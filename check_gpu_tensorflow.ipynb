# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)

# Check for GPU availability
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"✅ GPU is available: {len(gpus)} device(s) found.")
    for gpu in gpus:
        print(f"→ {gpu}")
else:
    print("❌ GPU is NOT available.")
# Out:
# WARNING:tensorflow:From e:\Project\Health-Prognosis\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow version: 2.15.0
# ❌ GPU is NOT available.

# %%
# Optional: Show all available devices
from tensorflow.python.client import device_lib
print("\nAvailable devices:\n", device_lib.list_local_devices())
# Out:
# Available devices:
#  [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14645062936937851330
# xla_global_id: -1
# ]
